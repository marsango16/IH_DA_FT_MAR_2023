# %% [markdown]
# ## Pandas Data Frames

# %% [markdown]
# - What Is Pandas?
# - Pandas vs Numpy
# - Pandas Data Frame Intro
# - Pandas Data Frame fundamental operations
#     - Creating
#     - Selecting/indexing
#     - Inserting rows/columns
#     - Setting data
#     - Filtering
#     - dropping rows/ columns
# - Dealing with Missing values

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from IPython.display import Image
from IPython.display import HTML
from IPython.display import Markdown, display
def printmd(string):
    display(Markdown(string))

# %%
from IPython.display import display,Image, HTML

CSS = """
.output {
    align-items: center;
}
div.output_area {
    width: 80%;
}
"""
HTML('<style>{}</style>'.format(CSS))
# Out:
# <style>
# .output {
#     align-items: center;
# }
# div.output_area {
#     width: 80%;
# }
# </style>

# %% [markdown]
# # What is Pandas?
#
#
# ### - Pandas is an open-source library built on top of Numpy Package.
# - https://github.com/pandas-dev/pandas
# - https://github.com/pandas-dev/pandas/blob/059c8bac51e47d6eaaa3e36d6a293a22312925e6/pandas/core/frame.py
#
# ### - Enables working with tabular and labeled data easily and intuitively
#
# ### - Pandas data structures are:
#     - Series
#     - Index
#     - Data Frame

# %% [markdown]
# ## Quick refresh to Numpy Arrays..
# - contains Numerical ***Homogeneous*** Data
# - may contain multi dimensional array elements.
# - used for performing various numerical computations and processing of the multidimensional and single-dimensional array elements.

# %%
import numpy as np
np.random.seed(0)  # seed for reproducibility

two_dim_arr = np.random.randint(10, size=(3, 4))  # Two-dimensional array
three_dim_arr = np.random.randint(10, size=(3, 4, 5))  # Three-dimensional array

# %% [markdown]
# ### A two dimensional Array example...

# %%
print("Two Dimentional Array")
two_dim_arr
# Out:
# Two Dimentional Array
# array([[5, 0, 3, 3],
#        [7, 9, 3, 5],
#        [2, 4, 7, 6]])

# %% [markdown]
# ### What I mean by Homogeneous...

# %%
print(two_dim_arr)

# %% [markdown]
# **two_dim_arr[0,0] = "Hello"**

# %%
#printmd("***Oops....***")
two_dim_arr[0,0] = "Hello"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28220/1899491190.py in <module>
#       1 #printmd("***Oops....***")
# ----> 2 two_dim_arr[0,0] = "Hello"
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %% [markdown]
# ### You can directly and simply form the DataFrame from the 2D array

# %%
import pandas as pd

# %%
print("Data Frame formed by 2D Array")
#printmd("***df=pd.DataFrame(two_dim_arr)***")
df=pd.DataFrame(two_dim_arr)
df

# %% [markdown]
# ### Pandas Data Frame is Heterogeneous!
# **df.iloc[0,0]="Hello"**

# %%
name = ['Festus', 'Angelica', 'Jupally', 'Ilkay']
fav_food = ['rice', 'pizza', 'dosa', 'doner']
py_score =[80,75,89,84]

# %%
students_dict = {'name':name, 'fav_food':fav_food, 'py_score':py_score}

# %%
students_df = pd.DataFrame(students_dict)

# %%
df=students_df

# %%
df.iloc[2,2]= '50'
df
# Out:
#        name fav_food py_score
# 0    Festus     rice       80
# 1  Angelica      NaN       75
# 2   Jupally     dosa       50
# 3     Ilkay    doner       84

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      4 non-null      object
#  1   fav_food  3 non-null      object
#  2   py_score  4 non-null      object
# dtypes: object(3)
# memory usage: 224.0+ bytes

# %%
names = ['Markus', 'Nilgun', 'Poppy', 'Marcel']
country = ['Germany', 'Turkey', 'UK', 'China']
pandas_score = [75, 80,90,68]
pets = ['No pet', 'cat', 'tiger', 'No pet']
pets_dict = {'names':names, 'countries':country,'pandas_score':pandas_score, 'pets':pets}

# %%
pets_dict

# %%
pets_df

# %%
pets_df  = pd.DataFrame(pets_dict)

# %%
pets_df.info()

# %% [markdown]
# ### Pandas Data Frame labels the data with Indices and Columns labels
# pd.DataFrame(np.random.randint(10,size=(3,2)),
#              columns=['foo', 'bar'],
#              index=['a', 'b', 'c'])

# %%
np.random.randint(10,size=(3,2))
# Out:
# array([[5, 9],
#        [4, 4],
#        [6, 4]])

# %%
##np.random.seed(0)
foo_df=pd.DataFrame(np.random.randint(10,size=(3,2)),
             columns=['foo', 'bar'],
             index=['a', 'b', 'c']
                 )

# %%
foo_df
# Out:
#    foo  bar
# a    4    3
# b    4    4
# c    8    4

# %% [markdown]
# ### Pandas DataFrame is relevant for statistical observations/data points with various variables (categorical, etc)

# %%
Image("res/Tidy_census.png")

# %% [markdown]
# ### It is intuitive...  Look how convenient it is!!

# %%
people_df= pd.read_csv("data/people.csv")
people_df
# Out:
#     name  age country
# 0    Pol   22      ES
# 1   Javi   20      ES
# 2  Maria   23      AR
# 3   Anna   24      FR
# 4   Anna   24      UK
# 5   Javi   30      MA
# 6    Dog    2      XX

# %%
Image('res/excel-to-pandas.png')

# %% [markdown]
# source: https://jalammar.github.io/

# %% [markdown]
# ### Describing the Data Frame...
# - df.Info()
# - df.count())
# - df.describe())
# - df.mean())

# %%
people_df
# Out:
#     name  age country
# 0    Pol   22      ES
# 1   Javi   20      ES
# 2  Maria   23      AR
# 3   Anna   24      FR
# 4   Anna   24      UK
# 5   Javi   30      MA
# 6    Dog    2      XX

# %%
people_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     7 non-null      object
#  1   age      7 non-null      int64
#  2   country  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %%
people_df['name'].describe()
# Out:
# count        7
# unique       5
# top       Javi
# freq         2
# Name: name, dtype: object

# %%
people_df.count()
# Out:
# name       7
# age        7
# country    7
# dtype: int64

# %%
x=[1,3,4,50]
print(np.median(x))
print(np.mean(x))
# Out:
# 3.5
# 14.5

# %%
#print(df,"\n")
people_df.info()
#print("df.count()  \n",df.count())
#print("\n df.describe() \n",df.describe())
#print("\n df.mean() \n",df.mean())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     7 non-null      object
#  1   age      7 non-null      int64
#  2   country  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# ### Pandas Data Frame operations

# %%
Image("res/CRUD.png")

# %% [markdown]
# ### Data Frame creation
# You can create/form a Data Frame from:
# - Dict of 1D ndarrays, lists, dicts, or Series
#
# - 2-D numpy.ndarray
#
# - Structured or record ndarray
#
# - A Series
#
# - Another DataFrame

# %% [markdown]
# #### Here is an example...

# %%
print('dic = {"col1": [1.0, 2.0, 3.0, 4.0], "col2": [4.0, 3.0, 2.0, 1.0]}\n')

dic = {"col1": [1.0, 2.0, 3.0, 4.0], "col2": [4.0, 3.0, 2.0, 1.0]}

dic

# %%
df=pd.DataFrame(dic,index =['a','b','c','d'])

# %%
df

# %% [markdown]
# #### creating Index for the Data frame...

# %%
df=pd.DataFrame(dic)
df

# %%
print('dic = {"col1": [1.0, 2.0, 3.0, 4.0], "col2": [4.0, 3.0, 2.0, 1.0]}\n')

dic2= {"col1": [1.0, 2.0, 3.0, 4.0], "col2": [4.0, 3.0, 2.0, 1.0]}

dic2

# %%
df2=pd.DataFrame(dic2)
df2

# %%
pets_df = pets_df.rename(columns={'pandas_score':'pandas score'})

# %%
pets_df

# %%
pets_df['pandas score']

# %%
pets_df['age'] = [5,5,5,5]

# %%
pets_df.drop(columns=['age'])

# %%
df3 = pd.concat([df,df2], axis=0)

# %%
df3.reset_index()

# %%
np.array(df["col1"])

# %% [markdown]
# ### Creating Data frame from Pandas Series objects..

# %%
d = {
       "apples": [3, 2, 0,1],
        "oranges": [0, 3, 7, 2],
    }

pd.DataFrame(d)

# %%
Image("res/series-and-dataframe.width-1200.png")

# %% [markdown]
# source: https://storage.googleapis.com/lds-media/images/series-and-dataframe.width-1200.png

# %% [markdown]
# ### Data Frame Selection / Indexing

# %%
data = {
    'name': ['Xavier', 'Ann', 'Jana', 'Yi', 'Robin', 'Amal', 'Nori'],
    'city': ['Mexico City', 'Toronto', 'Prague', 'Shanghai',
             'Manchester', 'Cairo', 'Osaka'],
    'age': [41, 28, 33, 34, 38, 31, 37],
    'py-score': [88.0, 79.0, 81.0, 80.0, 68.0, 61.0, 84.0]
}

row_labels = [101, 102, 103, 104, 105, 106, 107]
students_df = pd.DataFrame(data=data, index=row_labels)
students_df
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0
# 104      Yi     Shanghai   34      80.0
# 105   Robin   Manchester   38      68.0
# 106    Amal        Cairo   31      61.0
# 107    Nori        Osaka   37      84.0

# %%
students_df.index
# Out:
# Int64Index([101, 102, 103, 104, 105, 106, 107], dtype='int64')

# %%
students_df=students_df.drop(105)

# %%
students_df
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0
# 104      Yi     Shanghai   34      80.0
# 106    Amal        Cairo   31      61.0
# 107    Nori        Osaka   37      84.0

# %%
students_df.reset_index(drop=True)
# Out:
#      name         city  age  py-score
# 0  Xavier  Mexico City   41      88.0
# 1     Ann      Toronto   28      79.0
# 2    Jana       Prague   33      81.0
# 3      Yi     Shanghai   34      80.0
# 4    Amal        Cairo   31      61.0
# 5    Nori        Osaka   37      84.0

# %%
students_df.set_index('name')
# Out:
#                city  age  py-score
# name
# Xavier  Mexico City   41      88.0
# Ann         Toronto   28      79.0
# Jana         Prague   33      81.0
# Yi         Shanghai   34      80.0
# Amal          Cairo   31      61.0
# Nori          Osaka   37      84.0

# %% [markdown]
# ## Source: https://realpython.com/

# %% [markdown]
# ### data Selection

# %%
students_df.loc[[101],["age"]]
# Out:
#      age
# 101   41

# %%
students_df

# %% [markdown]
# ### Selecting by Label
# - .loc[]  function

# %%
students_df
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0
# 104      Yi     Shanghai   34      80.0
# 106    Amal        Cairo   31      61.0
# 107    Nori        Osaka   37      84.0

# %%
#print("students_df.loc[:, 'city']")
#students_df.loc[:, 'city']

# %%
print("students_df.loc[102:106, ['name', 'city']]")
students_df.loc[102,'name']
# Out:
# students_df.loc[102:106, ['name', 'city']]
# 'Ann'

# %%
students_df

# %%
#print('df["city"]')
cities = students_df[["name","city"]]
cities

# %%
print("df.city")
students_df.city

# %% [markdown]
# ### Selecting by Position
# - .iloc[]

# %%
students_df

# %%
pets_df

# %%
pets_df.set_index('names')

# %%
students_df.iloc[0,1]
# Out:
# 'Mexico City'

# %%
students_df.reset_index(drop=True,inplace=True)

# %%
sstudents_df =  students_df.drop('age',axis=1,inplace=True)

# %%
type(sstudents_df)
# Out:
# NoneType

# %%
print("students_df.iloc[1:6, [0, 1]]")
students_df.iloc[1:6, [0, 1]]
# Out:
# students_df.iloc[1:6, [0, 1]]
#      name      city
# 102   Ann   Toronto
# 103  Jana    Prague
# 104    Yi  Shanghai
# 106  Amal     Cairo
# 107  Nori     Osaka

# %% [markdown]
# ### Hmm.. Can you tell what is the difference between loc and iloc?

# %% [markdown]
# ### Setting/ Updating data

# %% [markdown]
# #### let us first update the Data frame index..

# %%
students_df
# Out:
#           city  py-score
# 0  Mexico City      88.0
# 1      Toronto      79.0
# 2       Prague      81.0
# 3     Shanghai      80.0
# 4        Cairo      61.0
# 5        Osaka      84.0

# %%
students_df.index = list(np.arange(0, 7))
students_df
# Out:
#      name         city  age  py-score
# 0  Xavier  Mexico City   41      88.0
# 1     Ann      Toronto   28      79.0
# 2    Jana       Prague   33      81.0
# 3      Yi     Shanghai   34      80.0
# 4   Robin   Manchester   38      68.0
# 5    Amal        Cairo   31      61.0
# 6    Nori        Osaka   37      84.0

# %%
students_df.index
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6], dtype='int64')

# %%
students_df.iloc[:4, 3] = [40, 50, 60, 70]
students_df
# Out:
#      name         city  age  py-score
# 0  Xavier  Mexico City   41      40.0
# 1     Ann      Toronto   28      50.0
# 2    Jana       Prague   33      60.0
# 3      Yi     Shanghai   34      70.0
# 4   Robin   Manchester   38      68.0
# 5    Amal        Cairo   31      61.0
# 6    Nori        Osaka   37      84.0

# %%
students_df.loc[5, 'py-score']
# Out:
# 61.0

# %%
students_df.loc[5, 'py-score'] = 70
students_df
# Out:
#      name         city  age  py-score
# 0  Xavier  Mexico City   41      40.0
# 1     Ann      Toronto   28      50.0
# 2    Jana       Prague   33      60.0
# 3      Yi     Shanghai   34      70.0
# 4   Robin   Manchester   38      68.0
# 5    Amal        Cairo   31      70.0
# 6    Nori        Osaka   37      84.0

# %%
students_df.loc[:,"py-score"]=90 
students_df
# Out:
#      name         city  age  py-score
# 0  Xavier  Mexico City   41        90
# 1     Ann      Toronto   28        90
# 2    Jana       Prague   33        90
# 3      Yi     Shanghai   34        90
# 4   Robin   Manchester   38        90
# 5    Amal        Cairo   31        90
# 6    Nori        Osaka   37        90

# %%
students_df.iloc[:, -1] = [88.0, 90, 81.0, 80.0, 68.0, 61.0, 84.0]
students_df
# Out:
#      name         city  age  py-score
# 0  Xavier  Mexico City   41      88.0
# 1     Ann      Toronto   28      90.0
# 2    Jana       Prague   33      81.0
# 3      Yi     Shanghai   34      80.0
# 4   Robin   Manchester   38      68.0
# 5    Amal        Cairo   31      61.0
# 6    Nori        Osaka   37      84.0

# %%
students_df

# %%
students_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7 non-null      object
#  1   city      7 non-null      object
#  2   age       7 non-null      int64
#  3   py-score  7 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 580.0+ bytes

# %%
students_df["py-score"]*=  1.5

# %%
students_df
# Out:
#      name         city  age  py-score
# 0  Xavier  Mexico City   41     132.0
# 1     Ann      Toronto   28     135.0
# 2    Jana       Prague   33     121.5
# 3      Yi     Shanghai   34     120.0
# 4   Robin   Manchester   38     102.0
# 5    Amal        Cairo   31      91.5
# 6    Nori        Osaka   37     126.0

# %%
students_df["py-score"]=list(map(lambda x: x+10,students_df["py-score"]))

# %%
students_df["py-score"] +=  10

# %%
students_df
# Out:
#      name         city  age  py-score
# 0  Xavier  Mexico City   41     142.0
# 1     Ann      Toronto   28     145.0
# 2    Jana       Prague   33     131.5
# 3      Yi     Shanghai   34     130.0
# 4   Robin   Manchester   38     112.0
# 5    Amal        Cairo   31     101.5
# 6    Nori        Osaka   37     136.0

# %%
students_df['fav_food'] = ['pizza', 'dosa', 'doner', 'rice', 'pommes', 'pierogi', 'tacos']

# %%
students_df
# Out:
#      name         city  age  py-score fav_food
# 0  Xavier  Mexico City   41     142.0    pizza
# 1     Ann      Toronto   28     145.0     dosa
# 2    Jana       Prague   33     131.5    doner
# 3      Yi     Shanghai   34     130.0     rice
# 4   Robin   Manchester   38     112.0   pommes
# 5    Amal        Cairo   31     101.5  pierogi
# 6    Nori        Osaka   37     136.0    tacos

# %%
students_df["numpy-score"]= students_df["py-score"] + students_df["age"]

# %%
students_df
# Out:
#      name         city  age  py-score fav_food  numpy-score
# 0  Xavier  Mexico City   41     142.0    pizza        183.0
# 1     Ann      Toronto   28     145.0     dosa        173.0
# 2    Jana       Prague   33     131.5    doner        164.5
# 3      Yi     Shanghai   34     130.0     rice        164.0
# 4   Robin   Manchester   38     112.0   pommes        150.0
# 5    Amal        Cairo   31     101.5  pierogi        132.5
# 6    Nori        Osaka   37     136.0    tacos        173.0

# %%
students_df['py-score']=students_df['py-score']*1.5

# %%
surnames = ['Schmidt','Bayrakdar','Nevin','Zhang']

# %%
pets_df['names']=pets_df['names']+ ' ' + surnames

# %%
pets_df

# %%
students_df.columns = ['index', 'name', 'city', 'age', 'py-score']

# %%
students_df.columns
# Out:
# Index(['name', 'city', 'age', 'py-score', 'fav_food', 'numpy-score'], dtype='object')

# %%
students_df[["age","py-score"]]
# Out:
#    age  py-score
# 0   41     142.0
# 1   28     145.0
# 2   33     131.5
# 3   34     130.0
# 4   38     112.0
# 5   31     101.5
# 6   37     136.0

# %%
type(students_df[["age"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Inserting/deleteing rows

# %%
students_df
# Out:
#      name         city  age  py-score fav_food  numpy-score
# 0  Xavier  Mexico City   41     142.0    pizza        183.0
# 1     Ann      Toronto   28     145.0     dosa        173.0
# 2    Jana       Prague   33     131.5    doner        164.5
# 3      Yi     Shanghai   34     130.0     rice        164.0
# 4   Robin   Manchester   38     112.0   pommes        150.0
# 5    Amal        Cairo   31     101.5  pierogi        132.5
# 6    Nori        Osaka   37     136.0    tacos        173.0

# %%
name = ['Juan', 'Monika', 'Juliette']
city = ['Berlin','Paris', 'Paris']
age = [30,20,25]

new_students = { 'name' : name, 'city':city, 'age':age}

# %%
new_df = pd.DataFrame(new_students)
new_df
# Out:
#        name    city  age
# 0      Juan  Berlin   30
# 1    Monika   Paris   20
# 2  Juliette   Paris   25

# %%
df = pd.concat([students_df,new_df])

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#        name         city  age  py-score
# 0    Xavier  Mexico City   41      88.0
# 1       Ann      Toronto   28      79.0
# 2      Jana       Prague   33      81.0
# 3        Yi     Shanghai   34      80.0
# 4     Robin   Manchester   38      68.0
# 5      Amal        Cairo   31      61.0
# 6      Nori        Osaka   37      84.0
# 7      Juan       Berlin   30       NaN
# 8    Monika        Paris   20       NaN
# 9  Juliette        Paris   25       NaN

# %%
students_df  = students_df[['name', 'city', 'age', 'py-score']]
students_df

# %%
Ronald = pd.Series(data=['Ronald', 'Berlin', 34, 79],
                 index=students_df.columns[0:4])
students_df= students_df.append(Ronald, ignore_index=True)
students_df

# %%
students_df.iloc[7,:]

# %%
Ronald = pd.Series(data=['Ronald', 'Berlin', 34, 79],
                 index=students_df.columns[0:4],name=21)

# %%
students_df=students_df.append(Ronald)

# %%
students_df

# %%
students_df.drop(labels=[7],inplace=True)

# %%
students_df

# %% [markdown]
# ### Inserting/Deleting columns

# %%
#print('df[js-score] = np.array([71.0, 95.0, 88.0, 79.0, 91.0, 91.0, 80.0])')
students_df['js-score'] =[71.0, 95.0, 88.0, 79.0, 91.0, 91.0, 80, 85]
students_df

# %%
students_df['py-score-updated'] = students_df['py-score'] * 10

# %%
students_df
# Out:
#        name         city  age  py-score  py-score-updated
# 101  Xavier  Mexico City   41      88.0             880.0
# 102     Ann      Toronto   28      79.0             790.0
# 103    Jana       Prague   33      81.0             810.0
# 104      Yi     Shanghai   34      80.0             800.0
# 105   Robin   Manchester   38      68.0             680.0
# 106    Amal        Cairo   31      61.0             610.0
# 107    Nori        Osaka   37      84.0             840.0

# %% [markdown]
# ### Inserting in a specific location

# %%
#print('df.insert(loc=4, column=js-score,value=np.array([86.0, 81.0, 78.0, 88.0, 74.0, 70.0, 81.0]))')
students_df.insert(loc=4, column='django-score',
          value=np.array([70, 74, 78, 56, 66, 78, 81.0]))
students_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27540/1577525160.py in <module>
#       1 #print('df.insert(loc=4, column=js-score,value=np.array([86.0, 81.0, 78.0, 88.0, 74.0, 70.0, 81.0]))')
# ----> 2 students_df.insert(loc=4, column='django-score',
#       3           value=np.array([70, 74, 78, 56, 66, 78, 81.0]))
#       4 students_df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    4412         if not allow_duplicates and column in self.columns:
#    4413             # Should this be a different kind of error??
# -> 4414             raise ValueError(f"cannot insert {column}, already exists")
#    4415         if not isinstance(loc, int):
#    4416             raise TypeError("loc must be int")
#
# ValueError: cannot insert django-score, already exists

# %% [markdown]
# ### dropping specific column

# %%
## axis= 0 dropping by row,  axis=1. ropping by column
students_df = students_df.drop(labels=['django-score'], axis=1)

# %%
students_df
# Out:
#        name         city  age  py-score  django-score  py-score-updated
# 101  Xavier  Mexico City   41      88.0          70.0             880.0
# 102     Ann      Toronto   28      79.0          74.0             790.0
# 103    Jana       Prague   33      81.0          78.0             810.0
# 104      Yi     Shanghai   34      80.0          56.0             800.0
# 105   Robin   Manchester   38      68.0          66.0             680.0
# 106    Amal        Cairo   31      61.0          78.0             610.0
# 107    Nori        Osaka   37      84.0          81.0             840.0

# %% [markdown]
# ### Filtering/Boolean Indexing

# %%
students_df["py-score"] >= 75
# Out:
# 101     True
# 102     True
# 103     True
# 104     True
# 105    False
# 106    False
# 107     True
# Name: py-score, dtype: bool

# %%
very_good_students_filter=students_df[students_df["py-score"]>=75]

# %%
very_good_students_filter
# Out:
#        name         city  age  py-score  django-score  py-score-updated
# 101  Xavier  Mexico City   41      88.0          70.0             880.0
# 102     Ann      Toronto   28      79.0          74.0             790.0
# 103    Jana       Prague   33      81.0          78.0             810.0
# 104      Yi     Shanghai   34      80.0          56.0             800.0
# 107    Nori        Osaka   37      84.0          81.0             840.0

# %% [markdown]
# ### Creating powerful filters with Logical operators AND, OR, NOT, XOR

# %%
#print('df[(df[py-score] >= 80) & (df[js-score] >= 80)]')
students_df[(students_df['py-score'] >= 200) | (students_df['django-score'] >= 80)] #or
# Out:
#      name   city  age  py-score  django-score  py-score-updated
# 107  Nori  Osaka   37      84.0          81.0             840.0

# %% [markdown]
# ## using value counts  function

# %%
people_df=pd.read_csv("data/people.csv")
people_df
# Out:
#     name  age country
# 0    Pol   22      ES
# 1   Javi   20      ES
# 2  Maria   23      AR
# 3   Anna   24      FR
# 4   Anna   24      UK
# 5   Javi   30      MA
# 6    Dog    2      XX

# %%
people_df["country"].nunique()
# Out:
# 6

# %%
people_df[people_df['name']=='Anna']
# Out:
#    name  age country
# 3  Anna   24      FR
# 4  Anna   24      UK

# %%
students_df['name']*2

# %%
pets_df

# %%
pets_df['pets'].unique()

# %%
pets_df

# %%
pets_df[pets_df['countries']=='UK']

# %%
pets_df

# %%
pets_df['age']=pets_df['age'].apply(lambda x: x**2)

# %%
pets_df.apply(lambda x: x**2 if type(x)==int else x)

# %%
people_df
# Out:
#     name  age country
# 0    Pol   22      ES
# 1   Javi   20      ES
# 2  Maria   23      AR
# 3   Anna   24      FR
# 4   Anna   24      UK
# 5   Javi   30      MA
# 6    Dog    2      XX

# %%
people_df['name']=people_df['name'].apply(lambda x: "John" if x=='Anna' else x)

# %%
people_df
# Out:
#     name  age country
# 0    Pol   22      ES
# 1   Javi   20      ES
# 2  Maria   23      AR
# 3   John   24      FR
# 4   John   24      UK
# 5   Javi   30      MA
# 6    Dog    2      XX

# %%
people_df['age']=people_df['age'].apply(lambda x: (x+20)/3)

# %%
people_df
# Out:
#     name        age country
# 0    Pol  14.000000      ES
# 1   Javi  13.333333      ES
# 2  Maria  14.333333      AR
# 3   John  14.666667      FR
# 4   John  14.666667      UK
# 5   Javi  16.666667      MA
# 6    Dog   7.333333      XX

# %%
people_df['name']  = people_df['name'].apply(lambda x: 'Evans' if x.startswith('J') else x)

# %%
people_df
# Out:
#     name        age country
# 0    Pol  14.000000      ES
# 1  Evans  13.333333      ES
# 2  Maria  14.333333      AR
# 3  Evans  14.666667      FR
# 4  Evans  14.666667      UK
# 5  Evans  16.666667      MA
# 6    Dog   7.333333      XX
